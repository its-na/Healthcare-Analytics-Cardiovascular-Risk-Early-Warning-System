# %%
import sys
sys.path.append('../') # Agar Jupyter bisa melihat folder src
from src.olah_data import load_data_kesehatan

df = load_data_kesehatan()
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='age', hue='target', kde=True, palette='magma')
plt.title('Distribusi Usia vs Risiko Penyakit Jantung')
plt.xlabel('Usia')
plt.ylabel('Jumlah Pasien')
plt.show()

# %%
from sqlalchemy import create_engine

# 1. Masukkan informasi yang benar di sini
user = 'postgres' # User default PostgreSQL
password = 'Oke123*' # Ganti dengan password pgAdmin kamu
host = 'localhost'
port = '5432'
db_name = 'db_health' # Sesuaikan dengan nama yang kamu buat di pgAdmin

# 2. Gabungkan menjadi alamat (URL)
url_db = f'postgresql://{user}:{password}@{host}:{port}/{db_name}'

# 3. Buat engine dan kirim data
try:
    engine = create_engine(url_db)
    df.to_sql('pasien_jantung', engine, if_exists='replace', index=False)
    print("Mantap! Data berhasil dikirim ke PostgreSQL!")
except Exception as e:
    print(f"Waduh, masih error nih. Pesannya: {e}")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\OneDrive\Desktop\portofolio_kesehatan\.venv\lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File ~\OneDrive\Desktop\portofolio_kesehatan\.venv\lib\site-packages\sqlalchemy\engine\base.py:3317, in Engine.raw_connection(self)
#    3296 """Return a "raw" DBAPI connection from the connection pool.
#    3297
#    3298 The returned object is a proxied version of the DBAPI
#    (...)
#    3315
#    3316 """
# -> 3317 return self.pool.connect()
#
# File ~\OneDrive\Desktop\portofolio_kesehatan\.venv\lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
# ...
